# %%
from concurrent.futures import ProcessPoolExecutor
from itertools import repeat
import math
from pathlib import Path
import re
from statistics import mean
import time
from typing import Iterator

from blist import sortedlist, blist
import numpy as np

from config import get_sessionmaker
from models import Page, PageLink, PageTalk, PageQuality

# %%
DATABASE_URI = "postgresql://postgres:postgres@localhost:5432/complete_wikipedia"
Session = get_sessionmaker(db_uri=DATABASE_URI)
s = Session()

# %%
results = s.query(
         Page, PageTalk, PageQuality,
    ).filter(
         PageQuality.page_id == PageTalk.page_id,
    ).filter(
         PageTalk.page_title == Page.page_title,
    ).all()

# %% [markdown]
# (<Page: (
# 	page_id=21345243,
# 	page_title='Marquis_de_Sade',
# 	)>, <PageTalk: (
# 	page_id=21345106,
# 	page_title='Marquis_de_Sade',
# 	)>, <PageQuality: (
# 	page_id=21345106,
# 	page_quality='B',
# 	)>)

# %%
for result in results:
    print(result)
    break
# Out:
# (<Page: (
# 	page_id=47419,
# 	page_title='Convenience_store',
# 	)>, <PageTalk: (
# 	page_id=47455,
# 	page_title='Convenience_store',
# 	)>, <PageQuality: (
# 	page_id=47455,
# 	page_quality='C',
# 	)>)

# %%
result_ids = []
for result in results:
    result_ids.append(result[0].page_id)
result_ids = np.array(result_ids)
np.save("data/high_quality_ids", result_ids)

# %%
result_ids = np.load("data/high_quality_ids.npy")
sl = sortedlist(result_ids)
del result_ids

# %%
# %%timeit
47419 in sl
# Out:
# 8.09 µs ± 78.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
47419 in result_ids
# Out:
# 138 µs ± 102 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
s.query(
         Page, PageTalk, PageQuality,
    ).filter(
         PageQuality.page_id == PageTalk.page_id,
    ).filter(
         PageTalk.page_title == Page.page_title,
    ).filter(
        Page.page_id == 25202,
    ).first()
# Out:
# (<Page: (
# 	page_id=25202,
# 	page_title='Quantum_mechanics',
# 	)>, <PageTalk: (
# 	page_id=19594240,
# 	page_title='Quantum_mechanics',
# 	)>, <PageQuality: (
# 	page_id=19594240,
# 	page_quality='GA',
# 	)>)

# %%
s.query(
         Page, PageTalk, PageQuality,
    ).filter(
         PageQuality.page_id == PageTalk.page_id,
    ).filter(
         PageTalk.page_title == Page.page_title,
    ).filter(
        Page.title_insensitive=="QuAnTum_mEchAnIcs",
    ).first()
# Out:
# (<Page: (
# 	page_id=25202,
# 	page_title='Quantum_mechanics',
# 	)>, <PageTalk: (
# 	page_id=19594240,
# 	page_title='Quantum_mechanics',
# 	)>, <PageQuality: (
# 	page_id=19594240,
# 	page_quality='GA',
# 	)>)

# %% [markdown]
# - 53008 lines
# - 1,420,256,990 links (all ns)
# - 626,327,844 links (ns 0 to all)
# - 561,899,045 links (ns 0 to ns 0)
# - at 6,301,566 ns 0 pages, 99.4 links/page (to all pages) & 89.1 links/page (to other ns 0 pages)

# %%
line_start = re.compile(b"INSERT INTO (.*?) VALUES ")
item_ex = re.compile(b"\((.*?),(.*?),(.*?),(.*?)\)")

# %%
def count_lines(line):
    return 1

def file_generator(file):
    for line in file:
        if line_start.search(line) is not None:
            yield line

def get_line_iterator(line) -> Iterator:
    if line_start.search(line) is not None:
        item_iter = item_ex.finditer(line)
        return item_iter
    else:
        return None


def get_items_in_line(line_iter):
    # sess_maker = get_sessionmaker(db_uri=DATABASE_URI)
    # sess = sess_maker()
    item_count = 0
    skip_count = 0
    links = []
    for entry in line_iter:
        if entry.group(4) == b"0" and entry.group(2) == b"0":
            pl_from = int(entry.group(1))
            pl_title = entry.group(3)
            if pl_from not in sl:
                skip_count += 1
                continue
            links.append([pl_from, pl_title])
            item_count += 1
    return [item_count, skip_count, links]


def process_file(path):
    with open(path, "rb") as f:
        line_iter = get_line_iterator(f.read())
        if line_iter is None:
            return None
        items = get_items_in_line(line_iter)
        return items

# %%
chunk_directory = Path("data/chunks")
item_counts = blist()
skip_counts = blist()
items = blist()
lookup = blist()
chunk_size = 7500
with ProcessPoolExecutor() as executor:
    for i, result in enumerate(executor.map(process_file, chunk_directory.iterdir())):
        if result is None:
            print("Error in regex for lines")
        item_counts.append(result[0])
        skip_counts.append(result[1])
        for item in result[2]:
            items.append(item)
        del result
        if i % chunk_size == 0:
            print(f"Counted {i} items:")
            avg_items = mean(item_counts[-chunk_size:])
            avg_skips = mean(skip_counts[-chunk_size:])
            print(f"chunk avg {avg_items} items")
            print(f"chunk avg {avg_skips} skips")
            start_time = time.time()
            print("starting sort")
            items.sort()
            delta = time.time() - start_time
            print(f"Finished sort in {delta/60} min")
# Out:
# Counted 0 items:
# chunk avg 0 items
# chunk avg 0 skips
# starting sort
# Finished sort in 4.251797993977865e-07 min
# Counted 7500 items:
# chunk avg 1713.2358666666667 items
# chunk avg 8678.794666666667 skips
# starting sort
# Finished sort in 0.594546898206075 min
# Counted 15000 items:
# chunk avg 1773.4085333333333 items
# chunk avg 8821.331333333334 skips
# starting sort
# Finished sort in 0.9705104509989421 min
# Counted 22500 items:
# chunk avg 1859.1426666666666 items
# chunk avg 9045.441066666666 skips
# starting sort
# Finished sort in 1.3678282936414083 min
# Counted 30000 items:
# chunk avg 1784.5790666666667 items
# chunk avg 8883.1452 skips
# starting sort
# Finished sort in 1.6144380529721578 min
# Counted 37500 items:
# chunk avg 1797.3246666666666 items
# chunk avg 8785.241066666667 skips
# starting sort
# Finished sort in 1.7807731628417969 min
# Counted 45000 items:
# chunk avg 1773.3138666666666 items
# chunk avg 8756.650666666666 skips
# starting sort
# Finished sort in 2.248443885644277 min
# Counted 52500 items:
# chunk avg 1752.7410666666667 items
# chunk avg 8760.868266666666 skips
# starting sort
# Finished sort in 2.384925349553426 min

# %%
start_time = time.time()
print("starting sort")
items.sort()
delta = time.time() - start_time
print(f"Finished sort in {delta/60} min")
# Out:
# starting sort
# Finished sort in 1.8410709818204245 min

# %%
# %%time
item = items.pop()
current_idx = item[0]
current_page = [current_idx, [item[1].decode("utf-8")]]
pl_added = 0
while True:
    try:
        item = items.pop()
        if item[0] == current_idx:
            current_page[1].append(item[1].decode("utf-8"))
        else:
            link = PageLink(
                pl_from=int(current_page[0]),
                pl_titles=current_page[1]
            )
            s.add(link)
            pl_added += 1
            if pl_added % 100 == 0:
                s.commit()
                print(f"added {pl_added} pages' links")
            current_idx = item[0]
            current_page = [current_idx, [item[1].decode("utf-8")]]
    except IndexError:
        link = PageLink(
            pl_from=current_page[0],
            pl_titles=current_page[1]
        )
        s.add(link)
        s.commit()
        break
# Out:
# links
# added 445300 pages' links
# added 445400 pages' links
# added 445500 pages' links
# added 445600 pages' links
# added 445700 pages' links
# added 445800 pages' links
# added 445900 pages' links
# added 446000 pages' links
# added 446100 pages' links
# added 446200 pages' links
# added 446300 pages' links
# added 446400 pages' links
# added 446500 pages' links
# added 446600 pages' links
# added 446700 pages' links
# added 446800 pages' links
# added 446900 pages' links
# added 447000 pages' links
# added 447100 pages' links
# added 447200 pages' links
# added 447300 pages' links
# added 447400 pages' links
# added 447500 pages' links
# added 447600 pages' links
# added 447700 pages' links
# added 447800 pages' links
# added 447900 pages' links
# added 448000 pages' links
# added 448100 pages' links
# added 448200 pages' links
# added 448300 pages' links
# added 448400 pages' links
# added 448500 pages' links
# added 448600 pages' links
# added 448700 pages' links
# added 448800 pages' links
# added 448900 pages' links
# added 449000 pages' links
# added 449100 pages' links
# added 449200 pages' links
# added 449300 pages' links
# added 449400 pages' links
# added 449500 pages' links
# added 449600 pages' links
# added 449700 pages' links
# added 449800 pages' links
# added 449900 pages' links
# added 450000 pages' links
# added 450100 pages' links
# added 450200 pages' links
# added 450300 pages' links
# added 450400 pages' links
# added 450500 pages' links
# added 450600 pages' links
# added 450700 pages' links
# added 450800 pages' links
# added 450900 pages' links
# added 451000 pages' links
# added 451100 pages' links
# added 451200 pages' links
# added 451300 pages' links
# added 451400 pages' links
# added 451500 pages' links
# added 451600 pages' links
# added 451700 pages' links
# added 451800 pages' links
# added 451900 pages' links
# added 452000 pages' links
# added 452100 pages' links
# added 452200 pages' links
# added 452300 pages' links
# added 452400 pages' links
# added 452500 pages' links
# added 452600 pages' links
# added 452700 pages' links
# added 452800 pages' links
# added 452900 pages' links
# added 453000 pages' links
# added 453100 pages' links
# added 453200 pages' links
# added 453300 pages' links
# added 453400 pages' links
# added 453500 pages' links
# added 453600 pages' links
# added 453700 pages' links
# added 453800 pages' links
# added 453900 pages' links
# added 454000 pages' links
# added 454100 pages' links
# added 454200 pages' links
# added 454300 pages' links
# added 454400 pages' links
# added 454500 pages' links
# added 454600 pages' links
# added 454700 pages' links
# added 454800 pages' links
# added 454900 pages' links
# added 455000 pages' links
# added 455100 pages' links
# added 455200 pages' links
# added 455300 pages' links
# added 455400 pages' links
# added 455500 pages' links
# added 455600 pages' links
# added 455700 pages' links
# added 455800 pages' links
# added 455900 pages' links
# added 456000 pages' links
# added 456100 pages' links
# added 456200 pages' links
# added 456300 pages' links
# added 456400 pages' links
# added 456500 pages' links
# added 456600 pages' links
# added 456700 pages' links
# added 456800 pages' links
# added 456900 pages' links
# added 457000 pages' links
# added 457100 pages' links
# added 512000 pages' links
# added 512100 pages' links
# added 512200 pages' links
# added 512300 pages' links
# added 512400 pages' links
# added 512500 pages' links
# added 512600 pages' links
# added 512700 pages' links
# added 512800 pages' links
# added 512900 pages' links
# added 513000 pages' links
# added 513100 pages' links
# added 513200 pages' links
# added 513300 pages' links
# added 513400 pages' links
# added 513500 pages' links
# added 513600 pages' links
# added 513700 pages' links
# added 513800 pages' links
# added 513900 pages' links
# added 514000 pages' links
# added 514100 pages' links
# added 514200 pages' links
# added 514300 pages' links
# added 514400 pages' links
# added 514500 pages' links
# added 514600 pages' links
# added 514700 pages' links
# added 514800 pages' links
# added 514900 pages' links
# added 515000 pages' links
# added 515100 pages' links
# added 515200 pages' links
# added 515300 pages' links
# added 515400 pages' links
# added 515500 pages' links
# added 515600 pages' links
# added 515700 pages' links
# added 515800 pages' links
# added 515900 pages' links
# added 516000 pages' links
# added 516100 pages' links
# added 516200 pages' links
# added 516300 pages' links
# added 516400 pages' links
# added 516500 pages' links
# added 516600 pages' links
# added 516700 pages' links
# added 516800 pages' links
# added 516900 pages' links
# added 517000 pages' links
# added 517100 pages' links
# added 517200 pages' links
# added 517300 pages' links
# added 517400 pages' links
# added 517500 pages' links
# added 517600 pages' links
# added 517700 pages' links
# added 517800 pages' links
# added 517900 pages' links
# added 518000 pages' links
# added 518100 pages' links
# added 518200 pages' links
# added 518300 pages' links
# added 518400 pages' links
# added 518500 pages' links
# added 518600 pages' links
# added 518700 pages' links
# added 518800 pages' links
# added 518900 pages' links
# added 519000 pages' links
# added 519100 pages' links
# added 519200 pages' links
# added 519300 pages' links
# added 519400 pages' links
# added 519500 pages' links
# added 519600 pages' links
# added 519700 pages' links
# added 519800 pages' links
# added 519900 pages' links
# added 520000 pages' links
# added 520100 pages' links
# added 520200 pages' links
# added 520300 pages' links
# added 520400 pages' links
# added 520500 pages' links
# added 520600 pages' links
# added 520700 pages' links
# added 520800 pages' links
# added 520900 pages' links
# added 521000 pages' links
# added 521100 pages' links
# added 521200 pages' links
# added 521300 pages' links
# added 521400 pages' links
# added 521500 pages' links
# added 521600 pages' links
# added 521700 pages' links
# added 521800 pages' links
# added 521900 pages' links
# added 522000 pages' links
# added 522100 pages' links

# %%
# chunk_directory = Path("data/chunks")
# item_counts = blist()
# skip_counts = blist()
# items = blist()
# lookup = blist()
# chunk_size = 2000
# with ProcessPoolExecutor() as executor:
#     for i, result in enumerate(executor.map(process_file, chunk_directory.iterdir())):
#         if result is None:
#             print("Error in regex for lines")
#         item_counts.append(result[0])
#         skip_counts.append(result[1])
#         for item in result[2]:
#             try:
#                 idx = lookup.index(item[1])
#                 items.append([item[0], idx])
#             except ValueError:
#                 lookup.append(item[1])
#                 idx = lookup.index(item[1])
#                 items.append([item[0], idx])
#         if i % chunk_size == 0:
#             print(f"Counted {i} items:")
#             avg_items = mean(item_counts[-chunk_size:])
#             avg_skips = mean(skip_counts[-chunk_size:])
#             print(f"chunk avg {avg_items} items")
#             print(f"chunk avg {avg_skips} skips")
#         del result

# %%
len(items)
# Out:
# 1574945

# %% [markdown]
# To run through whole link set:
# CPU times: user 17 s, sys: 1.73 s, total: 18.7 s
# Wall time: 14min 22s
#
# Running through and getting links:
# CPU times: user 1min 36s, sys: 8.03 s, total: 1min 44s
# Wall time: 15min 47s

# %%
whilte True:
    try:
        row =

# %%
items = sortedlist()

# %%
items.add(blist([4, 8]))

# %%
items.index()
# Out:
# sortedlist([blist([4, 1]), blist([4, 4]), blist([4, 5]), blist([4, 8])])

# %%
type(items[0])
# Out:
# list

# %%
items[:5]
# Out:
# nth'"],
#   [605120, b"'Rajinikanth'"],
#   [606490, b"'Rajinikanth'"],
#   [620504, b"'Rajinikanth'"],
#   [630081, b"'Rajinikanth'"],
#   [648216, b"'Rajinikanth'"],
#   [665443, b"'Rajinikanth'"],
#   [693943, b"'Rajinikanth'"],
#   [708039, b"'Rajinikanth'"],
#   [711707, b"'Rajinikanth'"],
#   [841432, b"'Rajinikanth'"],
#   [857051, b"'Rajinikanth'"],
#   [858980, b"'Rajinikanth'"],
#   [859118, b"'Rajinikanth'"],
#   [872828, b"'Rajinikanth'"],
#   [882809, b"'Rajinikanth'"],
#   [886858, b"'Rajinikanth'"],
#   [935787, b"'Rajinikanth'"],
#   [966831, b"'Rajinikanth'"],
#   [1024408, b"'Rajinikanth'"],
#   [1050838, b"'Rajinikanth'"],
#   [1075725, b"'Rajinikanth'"],
#   [1079155, b"'Rajinikanth'"],
#   [1114328, b"'Rajinikanth'"],
#   [1137487, b"'Rajinikanth'"],
#   [1163998, b"'Rajinikanth'"],
#   [1168455, b"'Rajinikanth'"],
#   [1176977, b"'Rajinikanth'"],
#   [1181499, b"'Rajinikanth'"],
#   [1202209, b"'Rajinikanth'"],
#   [1249907, b"'Rajinikanth'"],
#   [1280630, b"'Rajinikanth'"],
#   [1304177, b"'Rajinikanth'"],
#   [1307870, b"'Rajinikanth'"],
#   [1307996, b"'Rajinikanth'"],
#   [1313103, b"'Rajinikanth'"],
#   [1342873, b"'Rajinikanth'"],
#   [1355575, b"'Rajinikanth'"],
#   [1371262, b"'Rajinikanth'"],
#   [1418009, b"'Rajinikanth'"],
#   [1421615, b"'Rajinikanth'"],
#   [1470710, b"'Rajinikanth'"],
#   [1559135, b"'Rajinikanth'"],
#   [1575269, b"'Rajinikanth'"],
#   [1655812, b"'Rajinikanth'"],
#   [1691013, b"'Rajinikanth'"],
#   [1693032, b"'Rajinikanth'"],
#   [1704980, b"'Rajinikanth'"],
#   [1775706, b"'Rajinikanth'"],
#   [1817350, b"'Rajinikanth'"],
#   [1839078, b"'Rajinikanth'"],
#   [1847082, b"'Rajinikanth'"],
#   [1859572, b"'Rajinikanth'"],
#   [1862733, b"'Rajinikanth'"],
#   [1933148, b"'Rajinikanth'"],
#   [1933236, b"'Rajinikanth'"],
#   [1938728, b"'Rajinikanth'"],
#   [1941880, b"'Rajinikanth'"],
#   [1988078, b"'Rajinikanth'"],
b"'Rajinikanth:_The_Definitive_Biography'"],
#   [859131, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [1114328, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [2819679, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [2853175, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [2853200, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [3944660, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [4317586, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [4709385, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [5128234, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [6701449, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [8266590, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10628838, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10628894, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10628977, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10628994, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10640451, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10640723, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10640901, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10658791, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10791784, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10791894, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10792104, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [10811072, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [11143067, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [12481557, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [15858518, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [17124409, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [18471381, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [21027114, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [34638152, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [67095518, b"'Rajinikanth:_The_Definitive_Biography'"],
#   [613534, b"'Rajinikanth_filmography'"],
#   [20568124, b"'Rajinimurugan'"],
#   [28869194, b"'Rajinimurugan'"],
#   [40388009, b"'Rajinimurugan'"],
#   [40871034, b"'Rajinimurugan'"],
#   [41839006, b"'Rajinimurugan'"],
#   [344447, b"'Rajinovac'"],
#   [906647, b"'Rajinovac'"],
#   [22833573, b"'Rajinovac'"],
#   [36803795, b"'Rajinovac'"],
#   [40939318, b"'Rajinovac'"],
#   [50989298, b"'Rajinovac'"],
#   [51586734, b"'Rajinovac'"],
#   [61448443, b"'Rajinovac'"],
#   [37374972, b"'Rajion_Neal'"],
#   [40522782, b"'Rajion_Neal'"],
#   [3907314, b"'Rajisha_Vijayan'"],
#   [4454053, b"'Rajisha_Vijayan'"],
#   [5708792, b"'Rajisha_Vijayan'"],
#   [6605855, b"'Rajisha_Vijayan'"],
#   [6743683, b"'Rajisha_Vijayan'"],
#   [7120938, b"'Rajisha_Vijayan'"],
#   [8903995, b"'Rajisha_Vijayan'"],
#   [14790824, b"'Rajisha_Vijayan'"],
#   [14934572, b"'Rajisha_Vijayan'"],
#   [17695642, b"'Rajisha_Vijayan'"],
#   [21698413, b"'Rajisha_Vijayan'"],
#   [41899935, b"'Rajisha_Vijayan'"],
#   [43275506, b"'Rajisha_Vijayan'"],
#   [43280988, b"'Rajisha_Vijayan'"],
#   [50780196, b"'Rajisha_Vijayan'"],
#   [52731643, b"'Rajisha_Vijayan'"],
#   [63380980, b"'Rajisha_Vijayan'"],
#   [66055632, b"'Rajisha_Vijayan'"],
#   [67038019, b"'Rajisha_Vijayan'"],
#   [24410637, b"'Rajit_Kapoor'"],
#   [26393161, b"'Rajit_Kapoor'"],
#   [1828, b"'Rajit_Kapur'"],
#   [200145, b"'Rajit_Kapur'"],
#   [222346, b"'Rajit_Kapur'"],
#   [265130, b"'Rajit_Kapur'"],
#   [471623, b"'Rajit_Kapur'"],
#   [478225, b"'Rajit_Kapur'"],
#   [497619, b"'Rajit_Kapur'"],
#   [595801, b"'Rajit_Kapur'"],
#   [1085284, b"'Rajit_Kapur'"],
#   [1157225, b"'Rajit_Kapur'"],
#   [1157583, b"'Rajit_Kapur'"],
#   [1158886, b"'Rajit_Kapur'"],
#   [1606261, b"'Rajit_Kapur'"],
#   [1941880, b"'Rajit_Kapur'"],
#   [2034426, b"'Rajit_Kapur'"],
#   [3731898, b"'Rajit_Kapur'"],
#   [5140230, b"'Rajit_Kapur'"],
#   [5708792, b"'Rajit_Kapur'"],
#   [21690749, b"'Rajit_Kapur'"],
#   [23759568, b"'Rajit_Kapur'"],
#   [23904207, b"'Rajit_Kapur'"],
#   [26393161, b"'Rajit_Kapur'"],
#   [32043881, b"'Rajit_Kapur'"],
#   [38865970, b"'Rajit_Kapur'"],
#   [40143574, b"'Rajit_Kapur'"],
#   [41592837, b"'Rajit_Kapur'"],
#   [44918706, b"'Rajit_Kapur'"],
#   [47346504, b"'Rajit_Kapur'"],
#   [54822686, b"'Rajit_Kapur'"],
#   [58873997, b"'Rajit_Kapur'"],
#   [27494121, b"'Rajite'"],
#   [15274957, b"'Rajitha'"],
#   [15883386, b"'Rajitha'"],
#   [30456652, b"'Rajitha'"],
#   [33328232, b"'Rajitha'"],
#   [34937110, b"'Rajitha'"],
#   [35255529, b"'Rajitha'"],
#   [37688824, b"'Rajitha'"],
#   [40880066, b"'Rajitha'"],
#   [42436932, b"'Rajitha'"],
#   [42620557, b"'Rajitha'"],
#   [43284811, b"'Rajitha'"],
#   [50387695, b"'Rajitha'"],
#   [56864702, b"'Rajitha'"],
#   [57476006, b"'Rajitha'"],
#   [65552206, b"'Rajitha'"],
#   [4957815, b"'Rajitha_Hiran'"],
#   [10094963, b"'Rajitha_Hiran'"],
#   [21130711, b"'Rajitha_Hiran'"],
#   [22504627, b"'Rajitha_Hiran'"],
#   [33070974, b"'Rajitha_Hiran'"],
#   [35559348, b"'Rajitha_Hiran'"],
#   [36863438, b"'Rajitha_Hiran'"],
#   [38918600, b"'Rajitha_Hiran'"],
#   [46577290, b"'Rajitha_Hiran'"],
#   [55024105, b"'Rajitha_Hiran'"],
#   [57546193, b"'Rajitha_Hiran'"],
#   [60494764, b"'Rajitha_Hiran'"],
#   [60601107, b"'Rajitha_Hiran'"],
#   [60605413, b"'Rajitha_Hiran'"],
#   [60607875, b"'Rajitha_Hiran'"],
#   [60634705, b"'Rajitha_Hiran'"],
#   [60669867, b"'Rajitha_Hiran'"],
#   [60692862, b"'Rajitha_Hiran'"],
#   [60726750, b"'Rajitha_Hiran'"],
#   [60878110, b"'Rajitha_Hiran'"],
#   [60887152, b"'Rajitha_Hiran'"],
#   [61013577, b"'Rajitha_Hiran'"],
#   [61035582, b"'Rajitha_Hiran'"],
#   [61040721, b"'Rajitha_Hiran'"],
#   [61043029, b"'Rajitha_Hiran'"],
#   [61238399, b"'Rajitha_Hiran'"],
#   [61238744, b"'Rajitha_Hiran'"],
#   [61285186, b"'Rajitha_Hiran'"],
#   [61306912, b"'Rajitha_Hiran'"],
#   [61310281, b"'Rajitha_Hiran'"],
#   [61320416, b"'Rajitha_Hiran'"],
#   [61320596, b"'Rajitha_Hiran'"],
#   [61335617, b"'Rajitha_Hiran'"],
#   [61343209, b"'Rajitha_Hiran'"],
#   [61350043, b"'Rajitha_Hiran'"],
#   [61358253, b"'Rajitha_Hiran'"],
#   [61360517, b"'Rajitha_Hiran'"],
#   [61396443, b"'Rajitha_Hiran'"],
#   [61401660, b"'Rajitha_Hiran'"],
#   [61485373, b"'Rajitha_Hiran'"],
#   [61485670, b"'Rajitha_Hiran'"],
#   [61522301, b"'Rajitha_Hiran'"],
#   [61526658, b"'Rajitha_Hiran'"],
#   [61527103, b"'Rajitha_Hiran'"],
#   [61529638, b"'Rajitha_Hiran'"],
#   [61533574, b"'Rajitha_Hiran'"],
#   [61537835, b"'Rajitha_Hiran'"],
#   [61538473, b"'Rajitha_Hiran'"],
#   [61542178, b"'Rajitha_Hiran'"],
#   [61565158, b"'Rajitha_Hiran'"],
#   [61573158, b"'Rajitha_Hiran'"],
#   [61597002, b"'Rajitha_Hiran'"],
#   [61668547, b"'Rajitha_Hiran'"],
#   [61712854, b"'Rajitha_Hiran'"],
#   [61748994, b"'Rajitha_Hiran'"],
#   [61760489, b"'Rajitha_Hiran'"],
#   [61785829, b"'Rajitha_Hiran'"],
#   [61934193, b"'Rajitha_Hiran'"],
#   [61938863, b"'Rajitha_Hiran'"],
#   [62049756, b"'Rajitha_Hiran'"],
#   [62066133, b"'Rajitha_Hiran'"],
#   [62069094, b"'Rajitha_Hiran'"],
#   [62083729, b"'Rajitha_Hiran'"],
#   [62126563, b"'Rajitha_Hiran'"],
#   [62173197, b"'Rajitha_Hiran'"],
#   [62180239, b"'Rajitha_Hiran'"],
#   [62197425, b"'Rajitha_Hiran'"],
#   [62354198, b"'Rajitha_Hiran'"],
#   [62381081, b"'Rajitha_Hiran'"],
#   [62883144, b"'Rajitha_Hiran'"],
#   [63186083, b"'Rajitha_Hiran'"],
#   [63278474, b"'Rajitha_Hiran'"],
#   [63381915, b"'Rajitha_Hiran'"],
#   [63390310, b"'Rajitha_Hiran'"],
#   [64302961, b"'Rajitha_Hiran'"],
#   [64387462, b"'Rajitha_Hiran'"],
#   [64388166, b"'Rajitha_Hiran'"],
#   [64396376, b"'Rajitha_Hiran'"],
#   [64461116, b"'Rajitha_Hiran'"],
#   [64495497, b"'Rajitha_Hiran'"],
#   [64496276, b"'Rajitha_Hiran'"],
#   [64558294, b"'Rajitha_Hiran'"],
#   [64661452, b"'Rajitha_Hiran'"],
#   [66138336, b"'Rajitha_Hiran'"],
#   [66588814, b"'Rajitha_Hiran'"],
#   [66688951, b"'Rajitha_Hiran'"],
#   [66795239, b"'Rajitha_Hiran'"],
#   [66831669, b"'Rajitha_Hiran'"],
#   [66832797, b"'Rajitha_Hiran'"],
#   [66887685, b"'Rajitha_Hiran'"],
#   [66910346, b"'Rajitha_Hiran'"],
#   [66921519, b"'Rajitha_Hiran'"],
#   [66991792, b"'Rajitha_Hiran'"],
#   [67359248, b"'Rajitha_Hiran'"],
#   [67646602, b"'Rajitha_Hiran'"],
#   [57322226, b"'Rajitha_Pushpakumara'"],
#   [394969, b"'Rajitha_Senaratne'"],
#   [577400, b"'Rajitha_Senaratne'"],
#   [581583, b"'Rajitha_Senaratne'"],
#   [1388805, b"'Rajitha_Senaratne'"],
#   [3524112, b"'Rajitha_Senaratne'"],
#   [6584532, b"'Rajitha_Senaratne'"],
#   [7867639, b"'Rajitha_Senaratne'"],
#   [10121384, b"'Rajitha_Senaratne'"],
#   [13677073, b"'Rajitha_Senaratne'"],
#   [17375483, b"'Rajitha_Senaratne'"],
#   [18766070, b"'Rajitha_Senaratne'"],
#   [23306715, b"'Rajitha_Senaratne'"],
#   [23465333, b"'Rajitha_Senaratne'"],
#   [27193010, b"'Rajitha_Senaratne'"],
#   [27690256, b"'Rajitha_Senaratne'"],
#   [28789972, b"'Rajitha_Senaratne'"],
#   [28798622, b"'Rajitha_Senaratne'"],
#   [32561526, b"'Rajitha_Senaratne'"],
#   [35728449, b"'Rajitha_Senaratne'"],
#   [36492410, b"'Rajitha_Senaratne'"],
#   [38217691, b"'Rajitha_Senaratne'"],
#   [44163850, b"'Rajitha_Senaratne'"],
#   [44726940, b"'Rajitha_Senaratne'"],
#   [47472007, b"'Rajitha_Senaratne'"],
#   [47569584, b"'Rajitha_Senaratne'"],
#   [47586811, b"'Rajitha_Senaratne'"],
#   [56710443, b"'Rajitha_Senaratne'"],
#   [58898347, b"'Rajitha_Senaratne'"],
#   [60283949, b"'Rajitha_Senaratne'"],
#   [60550092, b"'Rajitha_Senaratne'"],
#   [60782835, b"'Rajitha_Senaratne'"],
#   [62404406, b"'Rajitha_Senaratne'"],
#   [62752684, b"'Rajitha_Senaratne'"],
#   [62843463, b"'Rajitha_Senaratne'"],
#   [62870818, b"'Rajitha_Senaratne'"],
#   [63272917, b"'Rajitha_Senaratne'"],
#   [63472309, b"'Rajitha_Senaratne'"],
#   [64776009, b"'Rajitha_Senaratne'"],
#   [26129, b"'Rajiv-Longowal_Accord'"],
#   [154649, b"'Rajiv-Longowal_Accord'"],
#   [34188537, b"'Rajiv-Longowal_Accord'"],
#   [230580, b"'Rajiv_Anchal'"],
#   [478225, b"'Rajiv_Anchal'"],
#   [996616, b"'Rajiv_Anchal'"],
#   [2822968, b"'Rajiv_Anchal'"],
#   [57322226, b"'Rajiv_Arokia'"],
#   [26129, b"'Rajiv_Awas_Yojana'"],
#   [243320, b"'Rajiv_Bajaj'"],
#   [2005390, b"'Rajiv_Bajaj'"],
#   [4107227, b"'Rajiv_Bajaj'"],
#   [49209200, b"'Rajiv_Bajaj'"],
#   [52224033, b"'Rajiv_Bajaj'"],
#   [63452182, b"'Rajiv_Bajaj'"],
#   [66573268, b"'Rajiv_Bajaj'"],
#   [37349484, b"'Rajiv_Banker'"],
#   [2345606, b"'Rajiv_Bhalla'"],
#   [25257, b"'Rajiv_Chandrasekaran'"],
#   [215113, b"'Rajiv_Chandrasekaran'"],
#   [416641, b"'Rajiv_Chandrasekaran'"],
#   [467003, b"'Rajiv_Chandrasekaran'"],
#   [732550, b"'Rajiv_Chandrasekaran'"],
#   [756944, b"'Rajiv_Chandrasekaran'"],
#   [918222, b"'Rajiv_Chandrasekaran'"],
#   [1104442, b"'Rajiv_Chandrasekaran'"],
#   [8443101, b"'Rajiv_Chandrasekaran'"],
#   [15365850, b"'Rajiv_Chandrasekaran'"],
#   [28920167, b"'Rajiv_Chandrasekaran'"],
#   [402402, b"'Rajiv_Chilaka'"],
#   [984639, b"'Rajiv_Chilaka'"],
#   [5869518, b"'Rajiv_Chilaka'"],
#   [9683846, b"'Rajiv_Chilaka'"],
#   [10640723, b"'Rajiv_Chilaka'"],
#   [33374981, b"'Rajiv_Chilaka'"],
#   [33853218, b"'Rajiv_Chilaka'"],
#   [57945810, b"'Rajiv_Chilaka'"],
#   [30874055, b"'Rajiv_Chowk_(Delhi_Metro)'"],
#   [22758151, b"'Rajiv_Chowk_metro_station'"],
#   [30874055, b"'Rajiv_Chowk_metro_station'"],
#   [403355, b"'Rajiv_Dayal_Mathur'"],
#   [65527246, b"'Rajiv_Dayal_Mathur'"],
#   [56566442, b"'Rajiv_Dhall'"],
#   [93149, b"'Rajiv_Dixit'"],
#   [96920, b"'Rajiv_Dixit'"],
#   [149330, b"'Rajiv_Dixit'"],
#   [234696, b"'Rajiv_Dixit'"],
#   [305365, b"'Rajiv_Dixit'"],
#   [327573, b"'Rajiv_Dixit'"],
#   [344768, b"'Rajiv_Dixit'"],
#   [384368, b"'Rajiv_Dixit'"],
#   [2644439, b"'Rajiv_Dixit'"],
#   [3869619, b"'Rajiv_Dixit'"],
#   [6271847, b"'Rajiv_Dixit'"],
#   [10682306, b"'Rajiv_Dixit'"],
#   [10682357, b"'Rajiv_Dixit'"],
#   [13486172, b"'Rajiv_Dixit'"],
#   [23231909, b"'Rajiv_Dixit'"],
#   ...]]

# %%
561899045/6301566
# Out:
# 89.16815994627368

# %%
with open("data/enwiki-20210520-pagelinks.sql", "rb") as file:
    for i, line in enumerate(file_generator(file)):
        f = open(f"data/chunks/{i}.sql", "wb")
        f.write(line)
        f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ddda66d40575> in <module>
#       1 breakpoint()
# ----> 2 with open("data/enwiki-20210520-pagelinks.sql", "rb") as file:
#       3     for i, line in enumerate(file_generator(file)):
#       4         f = open(f"data/chunks/{i}.sql", "wb")
#       5         f.write(line)
#
# <ipython-input-34-ddda66d40575> in <module>
#       1 breakpoint()
# ----> 2 with open("data/enwiki-20210520-pagelinks.sql", "rb") as file:
#       3     for i, line in enumerate(file_generator(file)):
#       4         f = open(f"data/chunks/{i}.sql", "wb")
#       5         f.write(line)
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ~/.vscode/extensions/ms-python.python-2021.5.926500501/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1935
#    1936             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1937                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1938
#    1939         frames_list = None
#
# ~/.vscode/extensions/ms-python.python-2021.5.926500501/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1970
#    1971             self.process_internal_commands()
# -> 1972             time.sleep(0.01)
#    1973
#    1974         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
# Out:
# PosixPath('data/chunks/28951.sql')

# %%
line_count
# Out:
# 53008

# %%
def test_func(a):
    return 1
test_list = [1,2,3,4,5,6,7]
with concurrent.futures.ProcessPoolExecutor() as executor:
    for result in executor.map(test_func, test_list)

# %%
# %%time
num_qualities = s.query(PageQuality).count()
offset = 0
limit = 50000
offset_multipliers = range(math.ceil(num_qualities/limit))
retrieved = 0

def scan_db(offset_multiplier):
    with Session() as sess:
        offset = offset_multiplier * limit
        results = sess.query(PageQuality).offset(offset).limit(limit)
    return offset_multiplier #results.count()

# for i in offset_multipliers:
#     retrieved += scan_db(i, limit)
#     print(f"retrieved {retrieved} entries")
# args = ((multiplier, limit) for multiplier in offset_multipliers)
with concurrent.futures.ProcessPoolExecutor() as executor:
    for result_count in executor.map(scan_db, offset_multipliers):
        retrieved += result_count
        print(f"retrieved {retrieved} entries")
# Out:
# retrieved 0 entries
# retrieved 1 entries
# retrieved 3 entries
# retrieved 6 entries
# retrieved 10 entries
# retrieved 15 entries
# retrieved 21 entries
# retrieved 28 entries
# retrieved 36 entries
# retrieved 45 entries
# retrieved 55 entries
# CPU times: user 13.4 ms, sys: 72.5 ms, total: 85.9 ms
# Wall time: 116 ms

# %%
# %%time
num_qualities = s.query(PageQuality).count()
offset = 0
limit = 50000
offset_multipliers = range(math.ceil(num_qualities/limit))
retrieved = 0

def scan_db(offset_multiplier):
    DATABASE_URI = "postgresql://postgres:postgres@localhost:5432/complete_wikipedia"
    sess_maker = get_sessionmaker(db_uri=DATABASE_URI)
    with sess_maker() as sess:
        offset = offset_multiplier * limit
        results = sess.query(PageQuality).offset(offset).limit(limit)
        for result in results:
            result.page_talk.page.page_title
    return results.count()

with concurrent.futures.ProcessPoolExecutor() as executor:
    for result_count in executor.map(scan_db, offset_multipliers):
        retrieved += result_count
        print(f"retrieved {retrieved} entries")
# Out:
# retrieved 50000 entries
# retrieved 100000 entries
# retrieved 150000 entries
# retrieved 200000 entries
# retrieved 250000 entries
# retrieved 300000 entries
# retrieved 350000 entries
# retrieved 400000 entries
# retrieved 450000 entries
# retrieved 500000 entries
# retrieved 522137 entries
# CPU times: user 19.1 ms, sys: 71.9 ms, total: 91 ms
# Wall time: 1min 7s

# %% [markdown]
# ## Loop through db:
# Series, 1 CPU:
# - CPU times: user 4min 52s
# - sys: 16.3 s
# - total: 5min 8s
# - Wall time: 6min 57s
#
# Parallel, 12 CPUs:
# - CPU times: user 19.1 ms
# - sys: 71.9 ms
# - total: 91 ms
# - Wall time: 1min 7s

# %%
result.page_talk.page
# Out:
# <Page: (
# 	page_id=733981,
# 	page_title='Flecainide',
# 	)>
